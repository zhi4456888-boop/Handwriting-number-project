# %% [markdown]
# # 手写数字识别项目 - 数据探索
#
# 本notebook用于探索MNIST数据集和模型训练过程

# %%
import sys
sys.path.append('../src')

from data_loader import load_mnist_data, preprocess_data, visualize_samples
import numpy as np
import matplotlib.pyplot as plt

# %%
# 加载数据
(x_train, y_train), (x_test, y_test) = load_mnist_data()

# %%
# 查看数据形状
print(f"训练集形状: {x_train.shape}")
print(f"测试集形状: {x_test.shape}")
print(f"标签范围: {y_train.min()} - {y_train.max()}")

# %%
# 可视化样本
visualize_samples(x_train, y_train, num_samples=10)
